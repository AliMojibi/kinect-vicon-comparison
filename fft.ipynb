# %%
import numpy as np
import matplotlib.pyplot as plt
import dataprocessor

# %%
dict_kinect, bones_kinect = dataprocessor.kinect_dict_data("G3-Kinect-RTK-P1T1-Unknown-C-0.txt")
dict_vicon, bones_vicon = dataprocessor.vicon_dict_data("G3-Vicon-RTK-P1T1-Unknown-C-0.txt")


kinect_rs = dict_kinect['ShoulderRight']
vicon_rs = dict_vicon['Right Shoulder']
kinect_ls = dict_kinect['ShoulderLeft']
vicon_ls = dict_vicon['Left Shoulder']
kinect_c = dict_kinect['SpineBase']
vicon_c = dict_vicon['Hips']
kinect_h = dict_kinect['Head']
vicon_h = dict_vicon['Head']
kinect_rf = dict_kinect['FootRight']
vicon_rf = dict_vicon['Right Foot']
kinect_lf = dict_kinect['FootLeft']
vicon_lf = dict_vicon['Left Foot']




kinect_data = [kinect_rs, kinect_ls, kinect_c, kinect_h, kinect_rf, kinect_lf]
vicon_data = [vicon_rs, vicon_ls, vicon_c, vicon_h, vicon_rf, vicon_lf]

# from numpy.fft import fft, ifft
sr = 30 
for data in kinect_data:
    for i in range(3): 
        X = np.fft.rfft(data[:, i])
        N = len(X)
        n = np.arange(N)
        T = N/sr
        freq = n/T 

        plt.figure(figsize = (12, 6))
        plt.subplot(121)

        plt.stem(freq, np.abs(X), 'b', \
                markerfmt=" ", basefmt="-b")
        plt.xlabel('Freq (Hz)')
        plt.ylabel('FFT Amplitude |X(freq)|')
        plt.xlim(0, 10)

        plt.subplot(122)
        plt.plot(np.fft.ifft(X), 'r')
        plt.xlabel('Time (s)')
        plt.ylabel('Amplitude')
        plt.tight_layout()

    plt.show()
# Out:
# c:\ProgramData\anaconda3\envs\scr\lib\site-packages\matplotlib\cbook\__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# from numpy.fft import fft, ifft
sr = 60 
for data in vicon_data:
    for i in range(3): 
        X = np.fft.rfft(data[:, i])
        N = len(X)
        n = np.arange(N)
        T = N/sr
        freq = n/T 

        plt.figure(figsize = (12, 6))
        plt.subplot(121)

        plt.stem(freq, np.abs(X), 'b', \
                markerfmt=" ", basefmt="-b")
        plt.xlabel('Freq (Hz)')
        plt.ylabel('FFT Amplitude |X(freq)|')
        plt.xlim(0, 10)

        plt.subplot(122)
        plt.plot(np.fft.ifft(X), 'r')
        plt.xlabel('Time (s)')
        plt.ylabel('Amplitude')
        plt.tight_layout()

    plt.show()
